# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammedshizin/NutriVision/blob/main/Plant_Disease_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

zip_ref = zipfile.ZipFile('/mydataset.zip', 'r')
zip_ref.extractall('/content/dataset')
zip_ref.close()

print("Dataset Extracted Successfully")
# Out:
# Dataset Extracted Successfully

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = "/content/dataset"

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 2873 images belonging to 1 classes.
# Found 718 images belonging to 1 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([

    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128, activation='relu'),

    Dense(3, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Model Created Successfully")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model Created Successfully

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)
# Out:
# Epoch 1/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.9889 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
model.save("plant_disease_model.h5")

print("Model Saved Successfully")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model Saved Successfully

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'dataset', '.ipynb_checkpoints', 'plant_disease_model.h5', 'sample_data']

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'test.jpg', '.ipynb_checkpoints', 'sample_data']

# %%
import os

for root, dirs, files in os.walk('/'):
    for file in files:
        if 'test' in file.lower():
            print(os.path.join(root, file))
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_retokenize_merge.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_graph.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_add_entities.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_pickle_doc.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_retokenize_split.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_creation.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_span_group.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_morphanalysis.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_array.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_span.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/doc/test_json_doc_conversion.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/matcher/test_matcher_logic.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/matcher/test_matcher_api.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/matcher/test_phrase_matcher.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/matcher/test_dependency_matcher.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/matcher/test_levenshtein.py
# /usr/local/lib/python3.12/dist-packages/spacy/tests/matcher/test_pattern_validation.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_problem.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_copy.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_nonlinear_atoms.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_lin_ops.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_gurobi_write.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_semidefinite_vars.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_linalg_utils.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_sign.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_conic_solvers.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_grad.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_complex.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_curvature.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_objectives.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test_errors.py
# /usr/local/lib/python3.12/dist-packages/cvxpy/tests/test
# /usr/local/lib/python3.12/dist-packages/pooch/tests/test_version.py
# /usr/local/lib/python3.12/dist-packages/pooch/tests/test_core.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_main_handling.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_spawn/test_threads.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_spawn/test_processes.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_spawn/test_misc.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_spawn/test_manager.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_fork/test_threads.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_fork/test_processes.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_fork/test_misc.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_fork/test_manager.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_forkserver/test_threads.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_forkserver/test_processes.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_forkserver/test_misc.py
# /usr/local/lib/python3.12/dist-packages/multiprocess/tests/test_multiprocessing_forkserver/test_manager.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/conftest.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/test_selection.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/test_streams.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/test_annotators.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/test_plotutils.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/test_renderclass.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/test_comms.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_hextilesplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_utils.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_callbacks.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_violinplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_radialheatmap.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_rasterplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_renderer.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_heatmapplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_overlayplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_barplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_curveplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_layoutplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_boxwhisker.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_vectorfieldplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_labels.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_graphplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_pointplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_sankey.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_histogramplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_quadmeshplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_spikeplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_elementplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_errorbarplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_distribution.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_pathplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_areaplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_annotationplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_scatter3d.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/matplotlib/test_plot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_hextilesplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_utils.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_callbacks.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_violinplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_tabular.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_radialheatmap.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_rasterplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_renderer.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_heatmapplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_subcoordy.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_overlayplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_divplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_barplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_curveplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_layoutplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_gridplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_vectorfieldplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_streaming.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_labels.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_graphplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_spreadplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_pointplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_sankey.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_histogramplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_links.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_quadmeshplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_boxwhiskerplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_elementplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_errorbarplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_multiaxis.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_server.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_tiles.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_pathplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_areaplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_annotationplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_geomplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_save.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_spikesplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/bokeh/test_plot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_callbacks.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_violinplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_renderer.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_scatterplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_barplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_curveplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_layoutplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_distributionplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_labelplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_scatter3dplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_gridplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_tableplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_imageplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_dynamic.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_figuresize.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_spreadplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_histogram.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_bivariateplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_shapeplots.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_path3d.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_surfaceplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_imagestack.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_quadmeshplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_boxwhiskerplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_elementplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_errorbarplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_dash.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_tiles.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_rgb.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_areaplot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/plotting/plotly/test_plot.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/operation/test_datashader.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/operation/test_downsample.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/operation/test_operation.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/operation/test_statsoperations.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/operation/test_timeseriesoperations.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_comparisonchart.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_graphelement.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_ellipsis.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_elementranges.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_apiconsistency.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_selection.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_comparisonraster.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_raster.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_annotations.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_comparisonpath.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_comparisonsimple.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_statselements.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_elementconstructors.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_image.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_paths.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_comparisondimension.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_tiles.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_elementselect.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/element/test_comparisoncomposite.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/test_optscompleter.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/test_parsers.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/test_displayhooks.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/test_notebooks.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/test_magics.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/notebooks/test_opts_image_line_magic.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/notebooks/test_opts_image_cell_magic_offset.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/notebooks/test_output_svg_line_magic.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ipython/notebooks/test_opts_image_cell_magic.ipynb
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_dimensions.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_utils.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_importexport.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_layers.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_dimensioned.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_tree.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_decollation.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_element.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_boundingregion.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_ndmapping.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_apply.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_layouts.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_collation.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_dynamic.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_operation.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_storeoptions.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_callable.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_archives.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_composites.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_prettyprint.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_datasetproperty.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_traversal.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/test_options.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_imageinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_multiinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_cudfinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_arrayinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_ibisinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_gridinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_xarrayinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_pandasinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_narwhalsinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_daskinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_spatialpandas.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_dictinterface.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/core/data/test_binneddatasets.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/util/test_utils.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/util/test_help.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/util/test_init.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/util/test_transform.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/util/test_locator.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_callback.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_histogram.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_layout.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_autorange.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_links.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_hover.py
# /usr/local/lib/python3.12/dist-packages/holoviews/tests/ui/bokeh/test_link_selections.py
# /usr/local/lib/python3.12/dist-packages/holoviews/examples/conftest.py
# /usr/local/lib/python3.12/dist-packages/starlette/testclient.py
# /usr/local/lib/python3.12/dist-packages/astropy/conftest.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/conftest.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_image_dask.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_nonstandard.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_diff.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_hdulist.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_tilde_path.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_structured.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_fitscheck.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_util.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_checksum.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_division.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_fitsdiff.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_uint.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_header.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_fitsinfo.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_groups.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_table.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_fsspec.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_image.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_convenience.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_fitsheader.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_fitstime.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_connect.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/test_core.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/data/test1.fits
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/data/test0.fits
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/tests/data/memtest.fits
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/hdu/compressed/tests/test_compressed.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/hdu/compressed/tests/conftest.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/hdu/compressed/tests/test_compression_failures.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/hdu/compressed/tests/test_fitsio.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/hdu/compressed/tests/test_checksum.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/fits/hdu/compressed/tests/test_tiled_compression.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_converter.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_tree.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_resource.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_util.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_exception.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_dataorigin.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_vo.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_coosys.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_ucd.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_table.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/test_schema_versions.py
# /usr/local/lib/python3.12/dist-packages/astropy/io/votable/tests/data/test.order.xml
# /usr/local/lib/python3.12/dist-packages/astropy/io/registry/tests/test_registry_help.py
# /usr/local/lib/python3.12/dist-packages/astropy/io
cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/__pycache__/conftest.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/__pycache__/test_connectionpool.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/__pycache__/test_queue_monkeypatch.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/__pycache__/test_ssltransport.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/__pycache__/test_poolmanager.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/__pycache__/test_wait.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/test_socks.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/test_pyopenssl.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/test_pyopenssl_dependencies.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/__pycache__/test_socks.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/__pycache__/test_pyopenssl_dependencies.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/__pycache__/test_pyopenssl.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/emscripten/conftest.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/emscripten/test_emscripten.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/emscripten/__pycache__/conftest.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/contrib/emscripten/__pycache__/test_emscripten.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_https.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_no_ssl.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_socketlevel.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_connection.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_connectionpool.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_proxy_poolmanager.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_poolmanager.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/test_chunked_transfer.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_https.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_proxy_poolmanager.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_connection.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_no_ssl.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_socketlevel.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_chunked_transfer.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_connectionpool.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/test/with_dummyserver/__pycache__/test_poolmanager.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/dummyserver/testcase.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/urllib3/dummyserver/__pycache__/testcase.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/httplib2/requirements-test.txt
# /tools/google-cloud-sdk/platform/gsutil/third_party/httplib2/.github/workflows/test.yaml
# /tools/google-cloud-sdk/platform/gsutil/third_party/httplib2/script/test
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/test-requirements.txt
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/test.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/test_lock.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/test_process_lock.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/test_decorators.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/test_helpers.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/__pycache__/test_lock.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/__pycache__/test_decorators.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/__pycache__/test_process_lock.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/tests/__pycache__/test_helpers.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/fasteners/fasteners/__pycache__/test.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc2511.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc5280.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc2315.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc2459.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc5208.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc4210.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc2560.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc5652.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc2437.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/test_rfc2314.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc2437.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc5208.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc2315.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc2560.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc5652.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc2314.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc5280.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc2511.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc2459.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1-modules/tests/__pycache__/test_rfc4210.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/funcsigs/tests/test_inspect.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/funcsigs/tests/test_formatannotation.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/funcsigs/tests/test_funcsigs.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/funcsigs/tests/__pycache__/test_funcsigs.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/funcsigs/tests/__pycache__/test_inspect.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/funcsigs/tests/__pycache__/test_formatannotation.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/six/test_six.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/six/__pycache__/test_six.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/test_debug.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/__pycache__/test_debug.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/test_streaming.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/ber/test_encoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/ber/test_decoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/ber/__pycache__/test_decoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/ber/__pycache__/test_encoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/__pycache__/test_streaming.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/cer/test_encoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/cer/test_decoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/cer/__pycache__/test_decoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/cer/__pycache__/test_encoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/der/test_encoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/der/test_decoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/der/__pycache__/test_decoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/der/__pycache__/test_encoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/native/test_encoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/native/test_decoder.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/native/__pycache__/test_decoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/codec/native/__pycache__/test_encoder.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_namedtype.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_opentype.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_univ.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_tag.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_constraint.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_useful.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_char.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/test_namedval.py
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_char.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_constraint.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_useful.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_univ.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_namedval.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_tag.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_namedtype.cpython-312.pyc
# /tools/google-cloud-sdk/platform/gsutil/third_party/pyasn1/tests/type/__pycache__/test_opentype.cpython-312.pyc
# /tools/google-cloud-sdk/platform/bq/third_party/google_reauth/all_tests.py
# /tools/google-cloud-sdk/platform/bq/third_party/google_reauth/__pycache__/all_tests.cpython-312.pyc
# /tools/google-cloud-sdk/platform/bq/third_party/google/apputils/basetest.py
# /tools/google-cloud-sdk/platform/bq/third_party/google/apputils/__pycache__/basetest.cpython-312.pyc
# /python-apt/tests/testcommon.py
# /python-apt/tests/test_cache_invocation.py
# /python-apt/tests/test_utils.py
# /python-apt/tests/test_hashsums.py
# /python-apt/tests/test_group.py
# /python-apt/tests/test_aptsources.py
# /python-apt/tests/test_all.py
# /python-apt/tests/test_progress.py
# /python-apt/tests/test_cve_2020_27351.py
# /python-apt/tests/test_lp659438.py
# /python-apt/tests/test_signed_usable.py
# /python-apt/tests/test_tagfile.py
# /python-apt/tests/test_size_to_str.py
# /python-apt/tests/test_deps.py
# /python-apt/tests/test_configuration.py
# /python-apt/tests/test_pyflakes.py
# /python-apt/tests/test_pep484.py
# /python-apt/tests/test_policy.py
# /python-apt/tests/test_auth.py
# /python-apt/tests/test_install_progress_exec.py
# /python-apt/tests/test_debfile.py
# /python-apt/tests/test_paths.py
# /python-apt/tests/test_aptsources_ports.py
# /python-apt/tests/test_lfs.py
# /python-apt/tests/test_hashes.py
# /python-apt/tests/test_large_file.py
# /python-apt/tests/test_apt_cache.py
# /python-apt/tests/test_debfile_multiarch.py
# /python-apt/tests/testmanual_pycodestyle.py
# /python-apt/tests/test_sourcerecords.py
# /python-apt/tests/data/test_debs/gdebi-test4.deb
# /python-apt/tests/data/test_debs/gdebi-test7.deb
# /python-apt/tests/data/test_debs/multiarch-test1_i386.deb
# /python-apt/tests/data/test_debs/gdebi-test13.deb
# /python-apt/tests/data/test_debs/gdebi-test3.deb
# /python-apt/tests/data/test_debs/gdebi-test1.deb
# /python-apt/tests/data/test_debs/gdebi-test10.deb
# /python-apt/tests/data/test_debs/gdebi-test2.deb
# /python-apt/tests/data/test_debs/gdebi-test5.deb
# /python-apt/tests/data/test_debs/testdep-allowed-any_1.0-1_i386.deb
# /python-apt/tests/data/test_debs/gdebi-test6.deb
# /python-apt/tests/data/test_debs/gdebi-test12.deb
# /python-apt/tests/data/test_debs/gdebi-test9.deb
# /python-apt/tests/data/test_debs/testdep-same-arch_1.0-1_i386.deb
# /python-apt/tests/data/test_debs/gdebi-test11.deb
# /python-apt/tests/data/test_debs/gdebi-test8.deb
# /python-apt/tests/data/aptsources/sources.list.testDuplication
# /python-apt/tests/data/aptsources/sources.list.testDistribution
# /python-apt/tests/data/hashsums/hashsum_test.data
# /python-apt/tests/data/hashsums/hashsum_test_with_zero.data
# /python-apt/tests/old/apt-test.py
# /python-apt/tests/old/test_enhances.py
# /python-apt/utils/mirrortest
# /python-apt/debian/tests/run-tests
# /python-apt/doc/examples/versiontest.py

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'test.jpg', '.ipynb_checkpoints', 'sample_data']

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img = image.load_img('/content/test.jpg', target_size=(128,128))

img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

img_array = img_array / 255.0

prediction = model.predict(img_array)

classes = list(train_data.class_indices.keys())

result = classes[np.argmax(prediction)]

print("Prediction:", result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10621/4170379035.py in <cell line: 0>()
#      12 prediction = model.predict(img_array)
#      13
# ---> 14 classes = list(train_data.class_indices.keys())
#      15
#      16 result = classes[np.argmax(prediction)]
#
# NameError: name 'train_data' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = "/content/dataset"

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10621/2407063283.py in <cell line: 0>()
#       8 )
#       9
# ---> 10 train_data = datagen.flow_from_directory(
#      11     dataset_path,
#      12     target_size=(128,128),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1134         keep_aspect_ratio=False,
#    1135     ):
# -> 1136         return DirectoryIterator(
#    1137             directory,
#    1138             self,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in __init__(self, directory, image_data_generator, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio, dtype)
#     454         if not classes:
#     455             classes = []
# --> 456             for subdir in sorted(os.listdir(directory)):
#     457                 if os.path.isdir(os.path.join(directory, subdir)):
#     458                     classes.append(subdir)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/dataset'

# %%
import zipfile

zip_ref = zipfile.ZipFile('/mydataset.zip', 'r')
zip_ref.extractall('/content/dataset')
zip_ref.close()

print("Dataset Extracted Successfully")
# Out:
# Dataset Extracted Successfully

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = "/content/dataset"

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 2873 images belonging to 1 classes.
# Found 718 images belonging to 1 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([

    Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128, activation='relu'),

    Dense(3, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Model Created Successfully")
# Out:
# Model Created Successfully

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)
# Out:
# Epoch 1/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - accuracy: 0.9896 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/5
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img = image.load_img('/content/test.jpg', target_size=(128,128))

img_array = image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

img_array = img_array / 255.0

prediction = model.predict(img_array)

classes = list(train_data.class_indices.keys())

result = classes[np.argmax(prediction)]

print("Prediction:", result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 957ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_10621/4170379035.py in <cell line: 0>()
#      14 classes = list(train_data.class_indices.keys())
#      15
# ---> 16 result = classes[np.argmax(prediction)]
#      17
#      18 print("Prediction:", result)
#
# IndexError: list index out of range

# %%
print(train_data.class_indices)
# Out:
# {'mydataset': 0}

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = "/content/dataset/mydataset"

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(128,128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 2873 images belonging to 3 classes.
# Found 718 images belonging to 3 classes.

# %%
print(train_data.class_indices)
# Out:
# {'Potato___Early_blight': 0, 'Potato___Late_blight': 1, 'Tomato_healthy': 2}

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load image
img = image.load_img('/content/test.jpg', target_size=(128,128))

# Convert to array
img_array = image.img_to_array(img)

# Expand dimensions
img_array = np.expand_dims(img_array, axis=0)

# Normalize
img_array = img_array / 255.0

# Predict
prediction = model.predict(img_array)

# Correct class names
classes = [
    'Potato___Early_blight',
    'Potato___Late_blight',
    'Tomato_healthy'
]

# Get prediction
result = classes[np.argmax(prediction)]

print("Prediction:", result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Prediction: Potato___Late_blight

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.136.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.11.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (26.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.26)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.15.11)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.24.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.46.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.13)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.29.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import gradio as gr
import numpy as np
from tensorflow.keras.preprocessing import image

# Class names
classes = [
    'Potato___Early_blight',
    'Potato___Late_blight',
    'Tomato_healthy'
]

# Prediction function
def predict_disease(img):

    img = img.resize((128,128))

    img_array = image.img_to_array(img)

    img_array = np.expand_dims(img_array, axis=0)

    img_array = img_array / 255.0

    prediction = model.predict(img_array)

    result = classes[np.argmax(prediction)]

    return result

# Interface
interface = gr.Interface(
    fn=predict_disease,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Plant Disease Detection",
    description="Upload a leaf image to detect disease"
)

interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://66abe66f88e17200d8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://66abe66f88e17200d8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
